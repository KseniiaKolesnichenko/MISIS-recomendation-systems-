# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, confusion_matrix
from sklearn.preprocessing import PolynomialFeatures


import plotly.express as px
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn import ensemble
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import r2_score

# %%
data=pd.read_csv('data\data.csv')
data.head()
# Out:
#    Unnamed: 0  Глубина_м  Нагрузка_на_долото_тонн  Скорость_ротора  \
# 0           0       7.80                      0.0               56
# 1           1       7.90                      0.0               56
# 2           2       8.01                      0.0               72
# 3           3       8.11                      0.0               72
# 4           4       8.20                      0.0               72
#
#    Плотность_на_входе_кг/м3  Расход_на_входе_литр/сек  Диам_скваж_мм  \
# 0                      1.01                   43.2682            324
# 1                      1.01                   42.9248            324
# 2                      1.01                   43.0965            324
# 3                      1.01                   43.0965            324
# 4                      1.01                   42.9248            324
#
#    Код_стратиграфии  №_скважины  Ср_мех_скорость_м/ч
# 0                20        6109               0.0690
# 1                20        6109               4.7368
# 2                20        6109               2.4444
# 3                20        6109               7.3469
# 4                20        6109               7.7143

# %%
data.shape
# Out:
# (174830, 10)

# %%
le_strat_code = LabelEncoder()

le_strat_code.fit(data['№_скважины'])
LabelEncoder()
list(le_strat_code.classes_)
data['№_скважины']=le_strat_code.transform(data['№_скважины'])

# %%
data.head()
# Out:
#    Unnamed: 0  Глубина_м  Нагрузка_на_долото_тонн  Скорость_ротора  \
# 0           0       7.80                      0.0               56
# 1           1       7.90                      0.0               56
# 2           2       8.01                      0.0               72
# 3           3       8.11                      0.0               72
# 4           4       8.20                      0.0               72
#
#    Плотность_на_входе_кг/м3  Расход_на_входе_литр/сек  Диам_скваж_мм  \
# 0                      1.01                   43.2682            324
# 1                      1.01                   42.9248            324
# 2                      1.01                   43.0965            324
# 3                      1.01                   43.0965            324
# 4                      1.01                   42.9248            324
#
#    Код_стратиграфии  №_скважины  Ср_мех_скорость_м/ч
# 0                20           2               0.0690
# 1                20           2               4.7368
# 2                20           2               2.4444
# 3                20           2               7.3469
# 4                20           2               7.7143

# %%
data['Код_стратиграфии'].value_counts()
# Out:
# 622    51906
# 621    16541
# 34     15868
# 361    14748
# 39     14565
# 61      9118
# 362     6430
# 35      6409
# 32      6294
# 360     6041
# 60      5750
# 31      4928
# 50      4322
# 40      3375
# 38      3180
# 37      2416
# 33      2128
# 20       798
# 10        13
# Name: Код_стратиграфии, dtype: int64

# %%
data['Код_стратиграфии'].unique()
# Out:
# array([ 20,  31,  32,  33,  34,  35, 361, 362,  37,  38,  39,  40,  50,
#         60,  61, 621, 622,  10, 360], dtype=int64)

# %%
data['Скорость_ротора'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Глубина_м'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Нагрузка_на_долото_тонн'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Плотность_на_входе_кг/м3'].hist()
# Out:
# <AxesSubplot:>

# %%
data['№_скважины'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Ср_мех_скорость_м/ч'].hist()
# Out:
# <AxesSubplot:>

# %%
len(data)
# Out:
# 174830

# %% [markdown]
# ### Код стратиграфии 361

# %%
data=data[data['Код_стратиграфии']==361]

# %%
#Сформируем датасет без кода стратиграфии
data=data.drop('Код_стратиграфии', axis=1)

# %%
data.head()
# Out:
#       Unnamed: 0  Глубина_м  Нагрузка_на_долото_тонн  Скорость_ротора  \
# 7154        7154     760.01                     14.0               60
# 7155        7155     760.12                     15.0               60
# 7156        7156     760.21                     17.0               60
# 7157        7157     760.33                     18.0               59
# 7158        7158     760.41                     15.0               60
#
#       Плотность_на_входе_кг/м3  Расход_на_входе_литр/сек  Диам_скваж_мм  \
# 7154                       1.2                   30.9059            178
# 7155                       1.2                   30.7342            178
# 7156                       1.2                   30.7342            178
# 7157                       1.2                   30.7342            178
# 7158                       1.2                   30.7342            178
#
#       №_скважины  Ср_мех_скорость_м/ч
# 7154           2                 50.4
# 7155           2                 39.6
# 7156           2                 36.0
# 7157           2                 48.0
# 7158           2                 48.0

# %%
y=data['Ср_мех_скорость_м/ч']
#X=data.iloc[:, 1:-1]

# %%
y.head()
# Out:
# 7154    50.4
# 7155    39.6
# 7156    36.0
# 7157    48.0
# 7158    48.0
# Name: Ср_мех_скорость_м/ч, dtype: float64

# %%
#X.head()

# %%
data['№_скважины'].value_counts()
# Out:
# 3    4673
# 0    4028
# 1    3187
# 2    2860
# Name: №_скважины, dtype: int64

# %%
data['Диам_скваж_мм'].value_counts()
# Out:
# 178    14748
# Name: Диам_скваж_мм, dtype: int64

# %%
sns.set(font_scale=1)
plt.subplots(figsize=(12, 12))
sns.heatmap(data.iloc[:, 1:].corr(), square=True,
              annot=True, fmt=".2f", linewidths=0., cmap="RdBu")
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='Глубина_м', y='Ср_мех_скорость_м/ч', data=data, fit_reg=False)
plt.show()

# %%
sns.regplot(x='Нагрузка_на_долото_тонн', y='Ср_мех_скорость_м/ч', data=data, fit_reg=False)
plt.show()

# %%
sns.regplot(x='Скорость_ротора', y='Ср_мех_скорость_м/ч', data=data, fit_reg=False)
plt.show()

# %%
sns.regplot(x='Плотность_на_входе_кг/м3', y='Ср_мех_скорость_м/ч', data=data, fit_reg=False)
plt.show()

# %%
sns.regplot(x='№_скважины', y='Ср_мех_скорость_м/ч', data=data, fit_reg=False)
plt.show()

# %%
data=data.drop(['Расход_на_входе_литр/сек','Диам_скваж_мм'], axis = 1)
data.head()
# Out:
#       Unnamed: 0  Глубина_м  Нагрузка_на_долото_тонн  Скорость_ротора  \
# 7154        7154     760.01                     14.0               60
# 7155        7155     760.12                     15.0               60
# 7156        7156     760.21                     17.0               60
# 7157        7157     760.33                     18.0               59
# 7158        7158     760.41                     15.0               60
#
#       Плотность_на_входе_кг/м3  №_скважины  Ср_мех_скорость_м/ч
# 7154                       1.2           2                 50.4
# 7155                       1.2           2                 39.6
# 7156                       1.2           2                 36.0
# 7157                       1.2           2                 48.0
# 7158                       1.2           2                 48.0

# %%
X=data.iloc[:, 1:-1]

# %%
sns.set(font_scale=1)
plt.subplots(figsize=(12, 12))
sns.heatmap(data.iloc[:, 1:].corr(), square=True,
              annot=True, fmt=".2f", linewidths=0., cmap="RdBu")
# Out:
# <AxesSubplot:>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
Model1=LinearRegression()
Model1.fit(X_train, y_train)
y_pred=Model1.predict(X_test)
y_pred;

# %%
print('MSE=', mean_squared_error(y_pred, y_test))
print('MAE=', mean_absolute_error(y_pred, y_test))
print ('R-squared=', Model1.score(X_train, y_train))
# Out:
# MSE= 322.9919381734945
# MAE= 13.072888058253968
# R-squared= 0.5670129014590795

# %% [markdown]
# ##### Полиномы

# %%
data_sq=data*data
data_sq.head()
# Out:
#       Unnamed: 0    Глубина_м  Нагрузка_на_долото_тонн  Скорость_ротора  \
# 7154    51179716  577615.2001                    196.0             3600
# 7155    51194025  577782.4144                    225.0             3600
# 7156    51208336  577919.2441                    289.0             3600
# 7157    51222649  578101.7089                    324.0             3481
# 7158    51236964  578223.3681                    225.0             3600
#
#       Плотность_на_входе_кг/м3  №_скважины  Ср_мех_скорость_м/ч
# 7154                      1.44           4              2540.16
# 7155                      1.44           4              1568.16
# 7156                      1.44           4              1296.00
# 7157                      1.44           4              2304.00
# 7158                      1.44           4              2304.00

# %%
X=data_sq.iloc[:,1:-1]
y=data_sq['Ср_мех_скорость_м/ч']
sns.set(font_scale=1)
plt.subplots(figsize=(12, 12))
sns.heatmap(pd.concat([X, y], axis=1).corr(), square=True,
              annot=True, fmt=".3f", linewidths=0.1, cmap="RdBu");

# %% [markdown]
# ##### Логарифмы

# %%
data_log=np.log(data)
data_log.head()
# Out:
#       Unnamed: 0  Глубина_м  Нагрузка_на_долото_тонн  Скорость_ротора  \
# 7154    8.875427   6.633332                 2.639057         4.094345
# 7155    8.875567   6.633476                 2.708050         4.094345
# 7156    8.875706   6.633595                 2.833213         4.094345
# 7157    8.875846   6.633753                 2.890372         4.077537
# 7158    8.875986   6.633858                 2.708050         4.094345
#
#       Плотность_на_входе_кг/м3  №_скважины  Ср_мех_скорость_м/ч
# 7154                  0.182322    0.693147             3.919991
# 7155                  0.182322    0.693147             3.678829
# 7156                  0.182322    0.693147             3.583519
# 7157                  0.182322    0.693147             3.871201
# 7158                  0.182322    0.693147             3.871201

# %%
X=data_log.iloc[:,1:-1]
X.head()
# Out:
#       Глубина_м  Нагрузка_на_долото_тонн  Скорость_ротора  \
# 7154   6.633332                 2.639057         4.094345
# 7155   6.633476                 2.708050         4.094345
# 7156   6.633595                 2.833213         4.094345
# 7157   6.633753                 2.890372         4.077537
# 7158   6.633858                 2.708050         4.094345
#
#       Плотность_на_входе_кг/м3  №_скважины
# 7154                  0.182322    0.693147
# 7155                  0.182322    0.693147
# 7156                  0.182322    0.693147
# 7157                  0.182322    0.693147
# 7158                  0.182322    0.693147

# %%
y=data_log['Ср_мех_скорость_м/ч']

# %%
sns.set(font_scale=1)
plt.subplots(figsize=(12, 12))
sns.heatmap(pd.concat([X, y], axis=1).corr(), square=True,
              annot=True, fmt=".3f", linewidths=0.1, cmap="RdBu");
